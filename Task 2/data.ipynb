# %%
import pandas as pd

df = pd.read_json('my_weather_data.json')
print(df)
# Out:
#            time                                 summary                 icon  \
# 0    1514782800               Clear throughout the day.            clear-day
# 1    1514869200               Clear throughout the day.            clear-day
# 2    1514955600  Mostly cloudy starting in the evening.  partly-cloudy-night
# 3    1515042000                  Foggy until afternoon.                  fog
# 4    1515128400               Clear throughout the day.            clear-day
# ..          ...                                     ...                  ...
# 360  1545886800  Mostly cloudy starting in the evening.  partly-cloudy-night
# 361  1545973200                     Rain until evening.                 rain
# 362  1546059600       Partly cloudy throughout the day.  partly-cloudy-night
# 363  1546146000       Mostly cloudy throughout the day.    partly-cloudy-day
# 364  1546232400         Rain starting in the afternoon.                 rain
#
# ...

# %%
df
# Out:
#            time                                 summary                 icon  \
# 0    1514782800               Clear throughout the day.            clear-day
# 1    1514869200               Clear throughout the day.            clear-day
# 2    1514955600  Mostly cloudy starting in the evening.  partly-cloudy-night
# 3    1515042000                  Foggy until afternoon.                  fog
# 4    1515128400               Clear throughout the day.            clear-day
# ..          ...                                     ...                  ...
# 360  1545886800  Mostly cloudy starting in the evening.  partly-cloudy-night
# 361  1545973200                     Rain until evening.                 rain
# 362  1546059600       Partly cloudy throughout the day.  partly-cloudy-night
# 363  1546146000       Mostly cloudy throughout the day.    partly-cloudy-day
# 364  1546232400         Rain starting in the afternoon.                 rain
#
# ...

# %%
df.columns
# Out:
# Index(['time', 'summary', 'icon', 'sunriseTime', 'sunsetTime', 'moonPhase',
#        'precipIntensity', 'precipIntensityMax', 'precipProbability',
#        'temperatureHigh', 'temperatureHighTime', 'temperatureLow',
#        'temperatureLowTime', 'apparentTemperatureHigh',
#        'apparentTemperatureHighTime', 'apparentTemperatureLow',
#        'apparentTemperatureLowTime', 'dewPoint', 'humidity', 'pressure',
#        'windSpeed', 'windGust', 'windGustTime', 'windBearing', 'cloudCover',
#        'uvIndex', 'uvIndexTime', 'visibility', 'temperatureMin',
#        'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime',
#        'apparentTemperatureMin', 'apparentTemperatureMinTime',
#        'apparentTemperatureMax', 'apparentTemperatureMaxTime', 'date',
#        'precipIntensityMaxTime', 'precipAccumulation', 'precipType'],
#       dtype='object')

# %%
df[['temperatureLow', 'temperatureHigh', 'temperatureMin', 'temperatureMax']].to_csv('weather_data.csv')
